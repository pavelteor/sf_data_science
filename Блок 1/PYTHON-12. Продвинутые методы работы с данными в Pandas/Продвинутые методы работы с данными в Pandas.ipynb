# %%
import pandas as pd

melb_df = pd.read_csv('melb_data_fe.csv')
melb_df.head()
# Out:
#        Suburb  Rooms   Type      Price Method SellerG        Date  Distance  \
# 0  Abbotsford      2  house  1480000.0      S  Biggin  2016-03-12       2.5
# 1  Abbotsford      2  house  1035000.0      S  Biggin  2016-04-02       2.5
# 2  Abbotsford      3  house  1465000.0     SP  Biggin  2017-04-03       2.5
# 3  Abbotsford      3  house   850000.0     PI  Biggin  2017-04-03       2.5
# 4  Abbotsford      4  house  1600000.0     VB  Nelson  2016-04-06       2.5
#
#    Postcode  Bedroom  ...  Longtitude             Regionname  Propertycount  \
# 0      3067        2  ...    144.9984  Northern Metropolitan           4019
# 1      3067        2  ...    144.9934  Northern Metropolitan           4019
# 2      3067        3  ...    144.9944  Northern Metropolitan           4019
# 3      3067        3  ...    144.9969  Northern Metropolitan           4019
# 4      3067        3  ...    144.9941  Northern Metropolitan           4019
#
# ...

# %%
display(melb_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 26 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Suburb           13580 non-null  object
#  1   Rooms            13580 non-null  int64
#  2   Type             13580 non-null  object
#  3   Price            13580 non-null  float64
#  4   Method           13580 non-null  object
#  5   SellerG          13580 non-null  object
#  6   Date             13580 non-null  object
#  7   Distance         13580 non-null  float64
#  8   Postcode         13580 non-null  int64
#  9   Bedroom          13580 non-null  int64
#  10  Bathroom         13580 non-null  int64
#  11  Car              13580 non-null  int64
#  12  Landsize         13580 non-null  float64
#  13  BuildingArea     13580 non-null  float64
#  14  CouncilArea      12211 non-null  object
#  15  Lattitude        13580 non-null  float64
# ...

# %% [markdown]
# Введение

# %%
import pandas as pd
melb_df["Date"] = pd.to_datetime(melb_df["Date"])
quartets = melb_df["Date"].dt.quarter
print(quartets.value_counts().iloc[1])
# Out:
# 4359

# %%
cols_to_exclude = ["Date","Rooms","Bedroom","Bathroom","Car"]
max_uniq_count = 150
for col in melb_df.columns:
    if melb_df[col].nunique() < max_uniq_count and col not in cols_to_exclude:
        melb_df[col] = melb_df[col].astype("category")
display(melb_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 26 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Suburb           13580 non-null  category
#  1   Rooms            13580 non-null  int64
#  2   Type             13580 non-null  category
#  3   Price            13580 non-null  float64
#  4   Method           13580 non-null  category
#  5   SellerG          13580 non-null  category
#  6   Date             13580 non-null  datetime64[ns]
#  7   Distance         13580 non-null  float64
#  8   Postcode         13580 non-null  int64
#  9   Bedroom          13580 non-null  int64
#  10  Bathroom         13580 non-null  int64
#  11  Car              13580 non-null  int64
#  12  Landsize         13580 non-null  float64
#  13  BuildingArea     13580 non-null  float64
#  14  CouncilArea      12211 non-null  category
#  15  Lattitude        13580 non-null  float64
# ...

# %% [markdown]
# МЕТОД SORT_VALUES()

# %%
melb_df.sort_values(by="Price").head(10)
# Out:
#                Suburb  Rooms   Type     Price Method        SellerG  \
# 2652        Footscray      1   unit   85000.0     PI        Burnham
# 1805            other      4  house  131000.0     PI          other
# 7303           Albion      1   unit  145000.0     PI         Biggin
# 1927           Coburg      4  house  145000.0     PI         Jellis
# 7940         Hawthorn      1   unit  160000.0     VB            HAR
# 12666       Brunswick      1   unit  170000.0     VB         Nelson
# 8811        Footscray      1   unit  170000.0     PI        Burnham
# 8504   West Footscray      1   unit  185000.0     PI            Jas
# 7293           Albion      1   unit  185000.0      S  hockingstuart
# 7305           Albion      2   unit  190000.0     SP        Burnham
#
#             Date  Distance  Postcode  Bedroom  ...  Longtitude  \
# 2652  2016-03-09       6.4      3011        1  ...   144.89000
# 1805  2017-02-25       8.9      3162        4  ...   145.02420
# ...

# %%
melb_df.sort_values(by="Date", ascending=True)
# Out:
#                Suburb  Rooms       Type      Price Method        SellerG  \
# 6183     Surrey Hills      2       unit   813000.0      S      Fletchers
# 6184     Surrey Hills      3      house  1205000.0      S      Fletchers
# 788    Bentleigh East      3  townhouse   760000.0     PI  hockingstuart
# 3821     Malvern East      4      house  1675000.0     PI        Thomson
# 4008      Middle Park      3      house  2600000.0     VB         Cayzer
# ...               ...    ...        ...        ...    ...            ...
# 10999           other      4      house   762000.0      S         Jellis
# 10998           other      3      house   830000.0     VB          other
# 10997           other      2       unit  1300000.0     SP          other
# 11019           other      3      house   904000.0     SP          other
# 11261      Yarraville      3      house   920000.0     PI        Village
#
#             Date  Distance  Postcode  Bedroom  ...  Longtitude  \
# ...

# %%
melb_df.sort_values(by=["Distance","Price"]).loc[::10,["Distance","Price"]]
# Out:
#        Distance      Price
# 11428       0.0   387000.0
# 10512       0.7   600000.0
# 5727        1.2   485000.0
# 8671        1.2   595000.0
# 5736        1.2   740000.0
# ...         ...        ...
# 12011      38.0   680000.0
# 10673      38.0   810000.0
# 13429      38.0  1155000.0
# 11102      41.0   650000.0
# 12728      45.9   650000.0
#
# [1358 rows x 2 columns]

# %%
melb_df.sort_values(by=["Price","Distance"]).loc[::10,["Price","Distance"]]
# Out:
#            Price  Distance
# 2652     85000.0       6.4
# 7116    200000.0       7.8
# 5206    220000.0      11.2
# 7240    241000.0       8.2
# 2898    250000.0      13.0
# ...          ...       ...
# 13341  4060000.0       6.3
# 8591   4275000.0       1.5
# 1094   4700000.0      11.2
# 5801   5046000.0       6.1
# 251    5525000.0       6.3
#
# [1358 rows x 2 columns]

# %%
mask1  = melb_df["AreaRatio"] < -0.8
mask2  = melb_df["Type"] == "townhouse"
mask3 = melb_df['SellerG'] == 'McGrath'
melb_df[mask1 & mask2 & mask3].sort_values(by=['Date', 'AreaRatio'], ascending=[True, False], ignore_index=True).loc[:,['Date', 'AreaRatio']]
# Out:
#         Date  AreaRatio
# 0 2016-07-26  -0.974922
# 1 2016-09-24  -0.971831
# 2 2016-11-27  -0.953608
# 3 2016-12-11  -0.945946
# 4 2017-08-04  -0.947368
# 5 2017-08-04  -0.970874

# %%
melb_df.sort_values(by="AreaRatio", ascending=False, ignore_index=True).loc[1558]
# Out:
# Suburb                       Elsternwick
# Rooms                                  2
# Type                               house
# Price                           716000.0
# Method                                 S
# SellerG                    hockingstuart
# Date                 2017-03-06 00:00:00
# Distance                             7.2
# Postcode                            3185
# Bedroom                                2
# Bathroom                               1
# Car                                    1
# Landsize                             0.0
# BuildingArea                       126.0
# CouncilArea                    Glen Eira
# Lattitude                      -37.89438
# Longtitude                     145.00851
# Regionname         Southern Metropolitan
# Propertycount                       4898
# MeanRoomsSquare                     25.2
# AreaRatio                            1.0
# MonthSale                              3
# AgeBuilding                           47
# ...

# %%
maski1  = melb_df["Rooms"] > 2
maski2  = melb_df["Type"] == "townhouse"
melb_df[maski1 & maski2].sort_values(by=['Rooms', 'MeanRoomsSquare'],
                                     ascending=[True, False], ignore_index=True).loc[18,"Price"]
# Out:
# 1300000.0

# %% [markdown]
# Группировка данных в DataFrame

# %%
melb_df.groupby(by="Type", as_index=False).mean()
# Out:
#         Type     Rooms         Price   Distance     Postcode   Bedroom  \
# 0      house  3.260874  1.242665e+06  10.979479  3104.080643  3.229336
# 1  townhouse  2.837522  9.337351e+05   9.851346  3100.777379  2.814183
# 2       unit  1.963871  6.051275e+05   7.607391  3110.797481  1.966523
#
#    Bathroom       Car    Landsize  BuildingArea  Lattitude  Longtitude  \
# 0  1.613822  1.772674  617.181924    152.162553 -37.803795  144.994700
# 1  1.809695  1.555655  279.606822    134.649710 -37.815782  144.996489
# 2  1.183295  1.128936  477.314219    102.235863 -37.823710  144.996363
#
#    Propertycount  MeanRoomsSquare  AreaRatio  AgeBuilding
# 0    7259.025505        18.996731  -0.490031    55.669700
# 1    7094.459605        18.569847  -0.094916    26.690305
# 2    8199.280080        21.068242   0.319883    39.703016

# %%
melb_df.groupby("Type")["Price"].mean()
# Out:
# Type
# house        1.242665e+06
# townhouse    9.337351e+05
# unit         6.051275e+05
# Name: Price, dtype: float64

# %%
melb_df.groupby('Regionname')['Distance'].min().sort_values(ascending=False)
# Out:
# Regionname
# Western Victoria              29.8
# Eastern Victoria              25.2
# Northern Victoria             21.8
# South-Eastern Metropolitan    14.7
# Eastern Metropolitan           7.8
# Western Metropolitan           4.3
# Southern Metropolitan          0.7
# Northern Metropolitan          0.0
# Name: Distance, dtype: float64

# %%
melb_df.groupby('MonthSale')['Price'].agg('describe')
# Out:
#             count          mean            std       min       25%        50%  \
# MonthSale
# 1           278.0  9.397921e+05  577668.924214  170000.0  570500.0   795000.0
# 2           333.0  1.169051e+06  671564.357417  131000.0  710000.0  1020000.0
# 3          1408.0  1.146762e+06  709573.596867   85000.0  680000.0   945000.0
# 4          1246.0  1.050479e+06  591892.902979  145000.0  655000.0   905500.0
# 5          1644.0  1.097807e+06  668492.867996  145000.0  650000.0   905000.0
# 6          1469.0  1.068981e+06  606010.069052  222000.0  660000.0   900000.0
# 7          1835.0  9.314698e+05  537390.803161  190000.0  586750.0   800000.0
# 8          1850.0  1.056371e+06  619617.476541  160000.0  635000.0   892000.0
# 9          1188.0  1.126349e+06  608734.690742  170000.0  725000.0   980000.0
# 10          854.0  1.135970e+06  692950.251627  250000.0  652625.0   950000.0
# 11          750.0  1.142503e+06  703666.227892  240000.0  671750.0   950000.0
# ...

# %%
melb_df.groupby('Regionname')['SellerG'].agg(
    		['nunique', set]
)
# Out:
#                             nunique  \
# Regionname
# Eastern Metropolitan             26
# Eastern Victoria                 11
# Northern Metropolitan            40
# Northern Victoria                11
# South-Eastern Metropolitan       25
# Southern Metropolitan            38
# Western Metropolitan             34
# Western Victoria                  6
#
#                                                                           set
# Regionname
# Eastern Metropolitan        {Barry, Ray, HAR, Noel, Woodards, Love, other,...
# Eastern Victoria            {C21, Barry, other, hockingstuart, Eview, Harc...
# Northern Metropolitan       {Hodges, Barry, Rendina, Eview, LITTLE, Cayzer...
# Northern Victoria           {Buckingham, Barry, other, hockingstuart, LITT...
# South-Eastern Metropolitan  {Hodges, Barry, Eview, Ray, HAR, Greg, Woodard...
# Southern Metropolitan       {Hodges, Barry, Rendina, Eview, LITTLE, Cayzer...
# ...

# %%
melb_df.groupby("Regionname")["Lattitude"].std().sort_values()
# Out:
# Regionname
# Western Victoria              0.011579
# Southern Metropolitan         0.043080
# Eastern Metropolitan          0.047890
# Northern Metropolitan         0.049639
# Western Metropolitan          0.051251
# South-Eastern Metropolitan    0.073411
# Northern Victoria             0.084455
# Eastern Victoria              0.147067
# Name: Lattitude, dtype: float64

# %% [markdown]
# Сводные таблицы

# %%
melb_df.groupby(["Rooms", "Type"])["Price"].mean().unstack().round()
# Out:
# Type       house  townhouse       unit
# Rooms
# 1       866866.0   592705.0   389929.0
# 2      1017238.0   710158.0   610491.0
# 3      1109233.0   984709.0   850596.0
# 4      1462283.0  1217092.0  1037476.0
# 5      1877327.0  1035000.0        NaN
# 6      1869508.0        NaN   520000.0
# 7      1920700.0        NaN        NaN
# 8      1510286.0        NaN  2250000.0
# 10      900000.0        NaN        NaN

# %%
melb_df.pivot_table(
    values='Price',
    index='Rooms',
    columns='Type',
    fill_value=".!."
).round()
# Out:
# Type       house      townhouse            unit
# Rooms
# 1       866866.0  592704.545455   389928.923203
# 2      1017238.0   710158.46395   610490.507509
# 3      1109233.0  984708.664547   850596.341463
# 4      1462283.0      1217092.0  1037476.190476
# 5      1877327.0      1035000.0             .!.
# 6      1869508.0            .!.        520000.0
# 7      1920700.0            .!.             .!.
# 8      1510286.0            .!.       2250000.0
# 10      900000.0            .!.             .!.

# %%
melb_df.pivot_table(values="Price",index="Regionname",columns="Weekend",aggfunc="count")
# Out:
# Weekend                        0     1
# Regionname
# Eastern Metropolitan         447  1024
# Eastern Victoria              13    40
# Northern Metropolitan       1258  2632
# Northern Victoria             11    30
# South-Eastern Metropolitan   123   327
# Southern Metropolitan       1534  3161
# Western Metropolitan         960  1988
# Western Victoria               8    24

# %%
melb_df.pivot_table(
    values='Landsize',
    index='Regionname',
    columns='Type',
    aggfunc=['median', 'mean'],
    fill_value=0
)
# Out:
#                            median                        mean              \
# Type                        house townhouse unit        house   townhouse
# Regionname
# Eastern Metropolitan        674.0     233.5  203   717.422847  269.440678
# Eastern Victoria            843.0       0.0  230  3108.960000    0.000000
# Northern Metropolitan       459.5     134.0    0   619.249092  317.325733
# Northern Victoria           724.0       0.0    0  3355.463415    0.000000
# South-Eastern Metropolitan  630.5     240.0  199   664.306701  212.160000
# Southern Metropolitan       586.0     246.0    0   569.643881  278.858824
# Western Metropolitan        531.0     198.0   62   507.883406  244.560669
# Western Victoria            599.5       0.0    0   655.500000    0.000000
#
#
# Type                              unit
# Regionname
# Eastern Metropolitan        330.444444
# Eastern Victoria            295.333333
# Northern Metropolitan       495.026538
# Northern Victoria             0.000000
# ...

# %%
pivot = melb_df.pivot_table(
    values='Price',
    index='SellerG',
    columns='Type',
    aggfunc= "mean",
    fill_value=0)


max_unit_price = pivot['unit'].max()
print(pivot[pivot['unit'] == max_unit_price].index[0])
# Out:
# Nick

# %% [markdown]
# Объединение DataFrame: знакомимся с новыми данными

# %%
import pandas as pd

ratings1 = pd.read_csv('ratings1.csv')
display(ratings1)
# Out:
#        userId  movieId  rating
# 0           1        1     4.0
# 1           1        3     4.0
# 2           1        6     4.0
# 3           1       47     5.0
# 4           1       50     5.0
# ...       ...      ...     ...
# 39996     274     5582     2.5
# 39997     274     5585     3.5
# 39998     274     5588     3.5
# 39999     274     5618     4.0
# 40000     274     5621     2.0
#
# [40001 rows x 3 columns]

# %%
import pandas as pd

ratings2 = pd.read_csv('ratings2.csv')
display(ratings2)
# Out:
#        userId  movieId  rating
# 0         274     5621     2.0
# 1         274     5630     3.0
# 2         274     5667     3.5
# 3         274     5679     3.5
# 4         274     5690     3.0
# ...       ...      ...     ...
# 60831     610   166534     4.0
# 60832     610   168248     5.0
# 60833     610   168250     5.0
# 60834     610   168252     5.0
# 60835     610   170875     3.0
#
# [60836 rows x 3 columns]

# %%
import pandas as pd

dates = pd.read_csv('dates.csv')
display(dates)
# Out:
#                        date
# 0       2000-07-30 18:45:03
# 1       2000-07-30 18:20:47
# 2       2000-07-30 18:37:04
# 3       2000-07-30 19:03:35
# 4       2000-07-30 18:48:51
# ...                     ...
# 100831  2017-05-03 21:53:22
# 100832  2017-05-03 22:21:31
# 100833  2017-05-08 19:50:47
# 100834  2017-05-03 21:19:12
# 100835  2017-05-03 21:20:15
#
# [100836 rows x 1 columns]

# %%
import pandas as pd

movies = pd.read_csv('movies.csv')
display(movies)
# Out:
#       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9737   193581  Black Butler: Book of the Atlantic (2017)
# 9738   193583               No Game No Life: Zero (2017)
# 9739   193585                               Flint (2017)
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 1                      Adventure|Children|Fantasy
# 2                                  Comedy|Romance
# 3                            Comedy|Drama|Romance
# ...

# %% [markdown]
# Объединение DataFrame: concat

# %%
raitings = pd.concat([ratings1,ratings2], ignore_index=True)
display(raitings)
# Out:
#         userId  movieId  rating
# 0            1        1     4.0
# 1            1        3     4.0
# 2            1        6     4.0
# 3            1       47     5.0
# 4            1       50     5.0
# ...        ...      ...     ...
# 100832     610   166534     4.0
# 100833     610   168248     5.0
# 100834     610   168250     5.0
# 100835     610   168252     5.0
# 100836     610   170875     3.0
#
# [100837 rows x 3 columns]

# %%
ratings = ratings.drop_duplicates(ignore_index=True)
print('Число строк в таблице ratings: ', ratings.shape[0])
# Число строк в таблице ratings: 100836
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\pavel\OneDrive\Desktop\Pavel\IDE\PYTHON-12. Продвинутые методы работы с данными в Pandas\Продвинутые методы работы с данными в Pandas.ipynb Cell 34' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/pavel/OneDrive/Desktop/Pavel/IDE/PYTHON-12.%20%D0%9F%D1%80%D0%BE%D0%B4%D0%B2%D0%B8%D0%BD%D1%83%D1%82%D1%8B%D0%B5%20%D0%BC%D0%B5%D1%82%D0%BE%D0%B4%D1%8B%20%D1%80%D0%B0%D0%B1%D0%BE%D1%82%D1%8B%20%D1%81%20%D0%B4%D0%B0%D0%BD%D0%BD%D1%8B%D0%BC%D0%B8%20%D0%B2%20Pandas/%D0%9F%D1%80%D0%BE%D0%B4%D0%B2%D0%B8%D0%BD%D1%83%D1%82%D1%8B%D0%B5%20%D0%BC%D0%B5%D1%82%D0%BE%D0%B4%D1%8B%20%D1%80%D0%B0%D0%B1%D0%BE%D1%82%D1%8B%20%D1%81%20%D0%B4%D0%B0%D0%BD%D0%BD%D1%8B%D0%BC%D0%B8%20%D0%B2%20Pandas.ipynb#ch0000033?line=0'>1</a> ratings = ratings.drop_duplicates(ignore_index=True)
# ...

# %%
ratings_dates = pd.concat([ratings,dates],axis = 1)
display(ratings_dates.tail(7))
# Out:
#         userId  movieId  rating                 date
# 100829     610   164179     5.0  2017-05-03 21:07:11
# 100830     610   166528     4.0  2017-05-04 06:29:25
# 100831     610   166534     4.0  2017-05-03 21:53:22
# 100832     610   168248     5.0  2017-05-03 22:21:31
# 100833     610   168250     5.0  2017-05-08 19:50:47
# 100834     610   168252     5.0  2017-05-03 21:19:12
# 100835     610   170875     3.0  2017-05-03 21:20:15

# %%
joined_false = ratings_dates.join(
    movies,
    rsuffix='_right',
    how='left'
)
display(joined_false)
# Out:
#         userId  movieId  rating                 date  movieId_right  \
# 0            1        1     4.0  2000-07-30 18:45:03            1.0
# 1            1        3     4.0  2000-07-30 18:20:47            2.0
# 2            1        6     4.0  2000-07-30 18:37:04            3.0
# 3            1       47     5.0  2000-07-30 19:03:35            4.0
# 4            1       50     5.0  2000-07-30 18:48:51            5.0
# ...        ...      ...     ...                  ...            ...
# 100831     610   166534     4.0  2017-05-03 21:53:22            NaN
# 100832     610   168248     5.0  2017-05-03 22:21:31            NaN
# 100833     610   168250     5.0  2017-05-08 19:50:47            NaN
# 100834     610   168252     5.0  2017-05-03 21:19:12            NaN
# 100835     610   170875     3.0  2017-05-03 21:20:15            NaN
#
#                                      title  \
# 0                         Toy Story (1995)
# 1                           Jumanji (1995)
# ...

# %%
joined = ratings_dates.join(
    movies.set_index('movieId'),
    on='movieId',
    how='left'
)
display(joined.head())
# Out:
#    userId  movieId  rating                 date                        title  \
# 0       1        1     4.0  2000-07-30 18:45:03             Toy Story (1995)
# 1       1        3     4.0  2000-07-30 18:20:47      Grumpier Old Men (1995)
# 2       1        6     4.0  2000-07-30 18:37:04                  Heat (1995)
# 3       1       47     5.0  2000-07-30 19:03:35  Seven (a.k.a. Se7en) (1995)
# 4       1       50     5.0  2000-07-30 18:48:51   Usual Suspects, The (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                               Comedy|Romance
# 2                        Action|Crime|Thriller
# 3                             Mystery|Thriller
# 4                       Crime|Mystery|Thriller

# %%
import re 
def get_year_release(arg):
    #находим все слова по шаблону "(DDDD)"
    candidates = re.findall(r'\(\d{4}\)', arg) 
    # проверяем число вхождений
    if len(candidates) > 0:
        #если число вхождений больше 0,
	#очищаем строку от знаков "(" и ")"
        year = candidates[0].replace('(', '')
        year = year.replace(')', '')
        return int(year)
    else:
        #если год не указан, возвращаем None
        return None

# %%
import pandas as pd

joined = pd.read_csv('ratings_movies.csv')
display(joined)
# Out:
#         Unnamed: 0  userId  movieId  rating                 date  \
# 0                0       1        1     4.0  2000-07-30 18:45:03
# 1                1       1        3     4.0  2000-07-30 18:20:47
# 2                2       1        6     4.0  2000-07-30 18:37:04
# 3                3       1       47     5.0  2000-07-30 19:03:35
# 4                4       1       50     5.0  2000-07-30 18:48:51
# ...            ...     ...      ...     ...                  ...
# 100831      100831     610   166534     4.0  2017-05-03 21:53:22
# 100832      100832     610   168248     5.0  2017-05-03 22:21:31
# 100833      100833     610   168250     5.0  2017-05-08 19:50:47
# 100834      100834     610   168252     5.0  2017-05-03 21:19:12
# 100835      100835     610   170875     3.0  2017-05-03 21:20:15
#
#                                  title  \
# 0                     Toy Story (1995)
# 1              Grumpier Old Men (1995)
# 2                          Heat (1995)
# ...

# %%
joined['year_release'] = joined['title'].apply(get_year_release)
joined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100836 entries, 0 to 100835
# Data columns (total 8 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Unnamed: 0    100836 non-null  int64
#  1   userId        100836 non-null  int64
#  2   movieId       100836 non-null  int64
#  3   rating        100836 non-null  float64
#  4   date          100836 non-null  object
#  5   title         100836 non-null  object
#  6   genres        100836 non-null  object
#  7   year_release  100818 non-null  float64
# dtypes: float64(2), int64(3), object(3)
# memory usage: 6.2+ MB

# %%
mask = joined['year_release'] == 2010
joined[mask].groupby('genres')['rating'].mean().sort_values()
# Out:
# genres
# Action|Sci-Fi                        1.000000
# Action|Adventure|Horror              1.500000
# Action|Drama|Fantasy                 1.500000
# Crime|Romance                        1.500000
# Adventure|Comedy|Fantasy             1.833333
#                                        ...
# Crime                                4.750000
# Comedy|Musical                       5.000000
# Animation|Drama|Fantasy|Mystery      5.000000
# Adventure|Children|Comedy|Mystery    5.000000
# Animation|Children|Mystery           5.000000
# Name: rating, Length: 119, dtype: float64

# %%
joined.groupby('userId')['genres'].nunique().sort_values(ascending=False)
# Out:
# userId
# 599    524
# 414    482
# 448    403
# 380    399
# 474    395
#       ...
# 578     15
# 12      15
# 85      13
# 214     13
# 245     13
# Name: genres, Length: 610, dtype: int64

# %%
joined.groupby('userId')['rating'].agg(
    ['count', 'mean']
).sort_values(['count', 'mean'], ascending=[True, False])
# Out:
#         count      mean
# userId
# 53         20  5.000000
# 595        20  4.200000
# 189        20  4.100000
# 569        20  4.000000
# 278        20  3.875000
# ...       ...       ...
# 274      1346  3.235884
# 448      1864  2.847371
# 474      2108  3.398956
# 599      2478  2.642050
# 414      2698  3.391957
#
# [610 rows x 2 columns]

# %%
import pandas as pd

joined = pd.read_csv('ratings_movies.csv')

joined["date"] = pd.to_datetime(joined["date"])
joined["year_rating"] = joined["date"].dt.year

pivot = joined.pivot_table(index="year_rating", columns="genres", values="rating", aggfunc="mean")
display(pivot)
# Out:
# genres       (no genres listed)    Action  Action|Adventure  \
# year_rating
# 1996                        NaN  2.730769          3.454545
# 1997                        NaN  3.538462          4.150000
# 1998                        NaN       NaN          4.200000
# 1999                        NaN       NaN          4.000000
# 2000                        NaN  2.588235          3.738462
# 2001                        NaN  3.000000          3.500000
# 2002                        NaN  2.750000          4.304348
# 2003                        NaN  3.833333          3.277778
# 2004                        NaN  2.700000          4.136364
# 2005                        NaN  3.357143          3.413043
# 2006                        NaN  2.166667          4.090909
# 2007                        NaN  2.583333          3.666667
# 2008                        NaN  3.000000          3.656250
# 2009                        NaN       NaN          3.714286
# ...

# %%
import pandas as pd

joined = pd.read_csv('ratings_movies.csv')

# %%
import pandas as pd

orders = pd.read_csv('orders.csv')
orders = pd.read_csv('products.csv')
display(orders)
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# c:\Users\pavel\OneDrive\Desktop\Pavel\IDE\PYTHON-12. Продвинутые методы работы с данными в Pandas\Продвинутые методы работы с данными в Pandas.ipynb Cell 46' in <cell line: 4>()
#       <a href='vscode-notebook-cell:/c%3A/Users/pavel/OneDrive/Desktop/Pavel/IDE/PYTHON-12.%20%D0%9F%D1%80%D0%BE%D0%B4%D0%B2%D0%B8%D0%BD%D1%83%D1%82%D1%8B%D0%B5%20%D0%BC%D0%B5%D1%82%D0%BE%D0%B4%D1%8B%20%D1%80%D0%B0%D0%B1%D0%BE%D1%82%D1%8B%20%D1%81%20%D0%B4%D0%B0%D0%BD%D0%BD%D1%8B%D0%BC%D0%B8%20%D0%B2%20Pandas/%D0%9F%D1%80%D0%BE%D0%B4%D0%B2%D0%B8%D0%BD%D1%83%D1%82%D1%8B%D0%B5%20%D0%BC%D0%B5%D1%82%D0%BE%D0%B4%D1%8B%20%D1%80%D0%B0%D0%B1%D0%BE%D1%82%D1%8B%20%D1%81%20%D0%B4%D0%B0%D0%BD%D0%BD%D1%8B%D0%BC%D0%B8%20%D0%B2%20Pandas.ipynb#ch0000045?line=0'>1</a> import pandas as pd
# ...

# %%
orders_products = orders.merge(
    products, 
    left_on='ID товара',
    right_on='Product_ID',
    how='left')
orders_products.tail(1)['Order ID']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\pavel\OneDrive\Desktop\Pavel\IDE\PYTHON-12. Продвинутые методы работы с данными в Pandas\Продвинутые методы работы с данными в Pandas.ipynb Cell 47' in <cell line: 1>()
#       <a href='vscode-notebook-cell:/c%3A/Users/pavel/OneDrive/Desktop/Pavel/IDE/PYTHON-12.%20%D0%9F%D1%80%D0%BE%D0%B4%D0%B2%D0%B8%D0%BD%D1%83%D1%82%D1%8B%D0%B5%20%D0%BC%D0%B5%D1%82%D0%BE%D0%B4%D1%8B%20%D1%80%D0%B0%D0%B1%D0%BE%D1%82%D1%8B%20%D1%81%20%D0%B4%D0%B0%D0%BD%D0%BD%D1%8B%D0%BC%D0%B8%20%D0%B2%20Pandas/%D0%9F%D1%80%D0%BE%D0%B4%D0%B2%D0%B8%D0%BD%D1%83%D1%82%D1%8B%D0%B5%20%D0%BC%D0%B5%D1%82%D0%BE%D0%B4%D1%8B%20%D1%80%D0%B0%D0%B1%D0%BE%D1%82%D1%8B%20%D1%81%20%D0%B4%D0%B0%D0%BD%D0%BD%D1%8B%D0%BC%D0%B8%20%D0%B2%20Pandas.ipynb#ch0000048?line=0'>1</a> orders_products = orders.merge(
# ...

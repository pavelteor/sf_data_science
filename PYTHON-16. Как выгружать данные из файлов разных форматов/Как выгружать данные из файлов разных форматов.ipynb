# %%
import pandas as pd
countries_data = pd.read_csv('countries.csv', sep=';')
countries_data.to_csv('countries.txt', index=False, sep=' ')

# %%
txt_df = pd.read_table('countries.txt', sep=' ', index_col=['country'])# Загружаем данные из файла в переменную, создавая объект DataFrame
display(txt_df) # Выводим содержимое DataFrame на экран
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\pavel\OneDrive\Desktop\Pavel\IDE\PYTHON-16. Как выгружать данные из файлов разных форматов\Как выгружать данные из файлов разных форматов.ipynb Cell 2 in <cell line: 1>()
# ...

# %%
melb_data = pd.read_csv('melb_data_ps.csv', header=None) # Загружаем данные из файла в переменную, создавая объект DataFrame
display(melb_data) # Выводим содержимое DataFrame на экран
# Out:
#           0              1                 2      3     4          5       6   \
# 0      index         Suburb           Address  Rooms  Type      Price  Method
# 1          0     Abbotsford      85 Turner St      2     h  1480000.0       S
# 2          1     Abbotsford   25 Bloomburg St      2     h  1035000.0       S
# 3          2     Abbotsford      5 Charles St      3     h  1465000.0      SP
# 4          3     Abbotsford  40 Federation La      3     h   850000.0      PI
# ...      ...            ...               ...    ...   ...        ...     ...
# 13576  13575  Wheelers Hill      12 Strada Cr      4     h  1245000.0       S
# 13577  13576   Williamstown     77 Merrett Dr      3     h  1031000.0      SP
# 13578  13577   Williamstown       83 Power St      3     h  1170000.0       S
# 13579  13578   Williamstown      96 Verdon St      4     h  2500000.0      PI
# 13580  13579     Yarraville        6 Agnes St      4     h  1285000.0      SP
#
# ...

# %%
data = pd.read_csv('ErrorEnCoding.csv', encoding = "utf-16", header=None ) # Считываем данные из файла с неизвестной кодировкой в переменную, создавая объект DataFrame
display(data) # Выводим содержимое DataFrame на экран
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# c:\Users\pavel\OneDrive\Desktop\Pavel\IDE\PYTHON-16. Как выгружать данные из файлов разных форматов\Как выгружать данные из файлов разных форматов.ipynb Cell 4 in <cell line: 1>()
# ...

# %%
from chardet.universaldetector import UniversalDetector # Импортируем субмодуль chardet.universaldetector
detector = UniversalDetector()
with open('ErrorEnCoding.csv', 'rb') as fh:
    for line in fh:
        detector.feed(line)
        if detector.done:
            break
detector.close()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\pavel\OneDrive\Desktop\Pavel\IDE\PYTHON-16. Как выгружать данные из файлов разных форматов\Как выгружать данные из файлов разных форматов.ipynb Cell 5 in <cell line: 1>()
# ...

# %%
data=pd.read_csv('ErrorEnCoding.csv', header=None ) # Считываем данные из файла с неизвестной кодировкой в переменную, создавая объект DataFrame
display(data) # Выводим содержимое DataFrame на экран
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# c:\Users\pavel\OneDrive\Desktop\Pavel\IDE\PYTHON-16. Как выгружать данные из файлов разных форматов\Как выгружать данные из файлов разных форматов.ipynb Cell 6 in <cell line: 1>()
# ...

# %%
data = pd.read_table('https://github.com/pavelteor/sf_data_science/blob/main/PYTHON-11.%20%D0%91%D0%B0%D0%B7%D0%BE%D0%B2%D1%8B%D0%B5%20%D0%BF%D1%80%D0%B8%D1%91%D0%BC%D1%8B%20%D1%80%D0%B0%D0%B1%D0%BE%D1%82%D1%8B%20%D1%81%20%D0%B4%D0%B0%D0%BD%D0%BD%D1%8B%D0%BC%D0%B8%20%D0%B2%20Pandas/melb_data.csv', sep=',')
display(data)
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# c:\Users\pavel\OneDrive\Desktop\Pavel\IDE\PYTHON-16. Как выгружать данные из файлов разных форматов\Как выгружать данные из файлов разных форматов.ipynb Cell 7 in <cell line: 1>()
# ...

# %%
data = pd.read_csv('students_performance.zip')
display(data)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
compression_opts = dict(method='zip', archive_name='out.csv') # Определяем параметры архивирования — метод сжатия, имя файл в архиве
data.to_csv('out.zip', index=False, compression=compression_opts)

# %%
grades = pd.read_excel('grades.xlsx', sheet_name='Maths')
display(grades.head())
# Out:
#    Student ID Student name  Grade
# 0           1          Аня      8
# 1           2         Катя      9
# 2           3         Маша      7
# 3           4         Миша      4
# 4           5         Женя      8

# %%
grades.to_excel('grades_new.xlsx') # Сохраняем данные из DataFrame grades в файл grades_new.xlsx в папке data

# %%
 grades.to_excel('grades_new.xlsx', sheet_name='Example', index=False) # Сохраняем данные из DataFrame grades в файл grades_new.xlsx (на листе 'Example') в папке data

# %%
ratings = pd.read_excel('ratings_movies.xlsx', sheet_name='ratings')
movies = pd.read_excel('ratings_movies.xlsx', sheet_name='movies')         
joined = ratings.merge(movies, on='movieId', how='left')         
joined.to_excel('joined.xlsx', sheet_name='JOINED', index=False)  
display(joined)
# Out:
#         userId  movieId  rating   timestamp                           title  \
# 0            1        1     4.0   964982703                Toy Story (1995)
# 1            1        3     4.0   964981247         Grumpier Old Men (1995)
# 2            1        6     4.0   964982224                     Heat (1995)
# 3            1       47     5.0   964983815     Seven (a.k.a. Se7en) (1995)
# 4            1       50     5.0   964982931      Usual Suspects, The (1995)
# ...        ...      ...     ...         ...                             ...
# 100831     610   166534     4.0  1493848402                    Split (2017)
# 100832     610   168248     5.0  1493850091   John Wick: Chapter Two (2017)
# 100833     610   168250     5.0  1494273047                  Get Out (2017)
# 100834     610   168252     5.0  1493846352                    Logan (2017)
# 100835     610   170875     3.0  1493846415  The Fate of the Furious (2017)
#
#                                              genres
# ...

# %%
import json # Импортируем модуль json

# %%
from pprint import pprint # Импортируем функцию pprint()

# %%
import requests
